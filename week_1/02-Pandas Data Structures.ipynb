# %%
import pandas as pd

# %%
s = pd.Series(['banana', 42])
s

# %%
s = pd.Series(['Wes', 'Creater'], index=['person', 'who'])
s

# %%
s.loc[0] # yields an error

# %%
s.loc['person']

# %%
s.iloc[0]

# %%
scientists=pd.DataFrame(
data={'Occupation':['Chemist','Statistician'],
'Born':['1920-07-25', '1876-06-13'],
'Died':['1958-04-16', '1937-10-16'],
'Age':[37,61]},
index=['Rosaline Franklin','William Gosset'],
columns=['Occupation', 'Born','Died','Age'])

# %%
scientists

# %%
scientists.reset_index() # try without inplace=True

# %%
scientists.reset_index(inplace=True) #

# %%
scientists = pd.read_csv('data/scientists.csv')

# %%
scientists

# %%
ages = scientists['Age']

# %%
ages

# %%
ages = scientists.Age
ages

# %%
type(ages)

# %%
ages.mean()

# %%
ages.std()

# %%
ages.median()

# %%
ages.quantile(0.5)

# %%
ages.quantile(.75)

# %%
ages.shape

# %%
ages.min()

# %%
ages.describe()

# %%
scientists.describe()

# %%
ages[ages > ages.mean()]

# %%
ages[(ages > 50) & (ages < 75)]

# %%
ages[(ages > ages.mean()) & ~(ages > 75)]

# %%
ages.describe()

# %%
ages + 100

# %%
scientists

# %%
scientists.columns

# %%
scientists.drop(['Age'], axis=1, inplace = True)
scientists.columns

# %%
s=pd.Series([37, 61, 90, 66, 56, 45, 41, 77] ) 
s

# %%
# add column to the dataframe
scientists['age']= s

# %%
scientists[scientists['Age'] > scientists['Age'].mean()]

# %%
scientists['Age'] > scientists['Age'].mean()

# %%
scientists

# %%
scientists.dtypes

# %%
# strftime
born_datetime = pd.to_datetime(scientists['Born'], format='%Y-%m-%d')

# %%
pd.to_datetime?

# %%
born_datetime

# %%
scientists['born_dt'] = born_datetime

# %%
# same as above
scientists['born_dt'] = pd.to_datetime(scientists['Born'], format='%Y-%m-%d')

# %%
scientists

# %%
scientists.info()

# %%
scientists['died_dt'] = pd.to_datetime(scientists['Died'], format='%Y-%m-%d')
scientists

# %%
scientists = scientists.drop(['Born', 'Died'], axis=1)

# %%
scientists

# %%
scientists.to_csv('scientists_clean.csv', index=False)

# %%
scientists = pd.read_csv('../data/scientists.csv', sep=',') # sep=',' is the default
scientists = pd.read_csv('../data/scientists.csv')
scientists = pd.read_csv('../data/scientists.csv', ',') # using positional argument passing for sep
print(scientists.head())

# %%
# drop multiple columns 

# remember you need to re-assign the 'dropped' dataframe or use inplace=True
scientists = scientists.drop(['Born', 'Died'], axis=1)
scientists.head()
