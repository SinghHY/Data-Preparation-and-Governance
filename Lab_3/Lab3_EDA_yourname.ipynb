# %% [markdown]
# #  EDA on `diabetes.csv`
#
# #  Lab: Lab  3
#
# ---
#
#
#
# ## 👤 Student Information
#
# | Field           	| Entry (fill in)                |
# |-----------------|--------------------------------|
# | **Name**        |   |
# | **Student #**   | _Type your student number_     |
# | **Course/Section** |AIG150 NAA    |
# | **Date**        |                  |

# %%
import pandas as pd, numpy as np, os, matplotlib.pyplot as plt

# %% [markdown]
# ## Q0) Load the Dataset
# ** Read `diabetes.csv` into `df`, show head & dtypes.

# %% [markdown]
# ## Q1) Inspect dtypes and display it.

# %% [markdown]
# ## Q2) Frequency Distribution
#  Q2.** Frequency of all columns

# %% [markdown]
# ## 3) Descriptive Statistics (Numerical)
# ** Show `describe()` (numeric) + missing counts for all columns.

# %% [markdown]
# ## 4) Bivariate Analysis
# ** Calculate mean Glucose for Outcome 0 and Outcome 1
# ** Calculate the correlation between Glucose and BMI, ensuring only numeric columns are used

# %% [markdown]
# ## 5) Boxplot
# ** Boxplot `Glucose` by `Outcome` (matplotlib).

# %% [markdown]
# ## 6) Multivariate Analysis
# ** Correlation heatmap of numeric features.

# %% [markdown]
# ## 7) Histograms
# ** Histograms for `Glucose`, `BMI`, `Age` (one chart per feature).

# %% [markdown]
# ## 8) Skewness & Kurtosis vs Gaussian
# ** For `Glucose`: compute skew/kurt; plot histogram (density=True) + Normal PDF.

# %% [markdown]
# ## 9) Binning: 4 Fixed-Width
# ** `pd.cut` on `Age` into 4 bins; show counts & proportions.

# %% [markdown]
# ## 10) Binning: 4 Quantiles
# ** `pd.qcut` on `BMI` into 4 quantiles; show counts & proportions.
